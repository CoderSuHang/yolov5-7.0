# %%
import torch

# Model
model = torch.hub.load("./", "yolov5s", source="local")

# Images
img = "./data/images/zidane.jpg"

# Inference
results = model(img)

# Results
results.show()
# Out:
# YOLOv5  2022-11-22 Python-3.8.18 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x1B3DD2A10A0>
